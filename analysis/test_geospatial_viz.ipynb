# %%
from geopy.geocoders import Nominatim
from geopandas import gpd
import pandas as pd
import numpy as np
import folium

# %%
address='Sheung Shui'
geolocator = Nominatim(user_agent="Your_Name")
location = geolocator.geocode(address)
print(location.address)
print((location.latitude, location.longitude))
# Out:
# 上水 Sheung Shui, 北區 North District, 新界 New Territories, 香港 Hong Kong, 518005, 中国
# (22.5014146, 114.1287033)

# %%
# remove nan to test
districts = ['Kowloon Bay', 'Tai Koo', 'Ngau Tau Kok', 'Lantau Island',
'district', 'Sheung Wan', 'Shatin Area', 'Tung Chung', 'Aberdeen',
'Tseung Kwan O', 'Chai Wan', 'Central', 'Central & Western Area',
'Quarry Bay', 'Wan Chai', 'Admiralty', 'Kwai Hing',
'Overseas', 'Airport Area', 'Southern Area', 'Tsim Sha Tsui',
'Kwun Tong', 'Tsing Yi', 'Tai Po Area', 'Others', 'North Point',
'Hung Hom', 'Kwun Tong Area', 'Causeway Bay', 'Kwai Tsing Area',
'Lai Chi Kok', 'Yau Tsim Mong Area', 'Cheung Sha Wan',
'Wong Tai Sin Area', 'Sai Wan Ho', 'Tin Hau', 'Tsuen Wan Area',
'Shau Kei Wan', 'Mong Kok']

# %%
# important parameters
file_name = 'data-scientist-2022-12-06-1.csv'
df_raw = pd.read_csv(file_name)

# %%
df_1 = df_raw.copy()

# %%
df_1['district'].replace('district',np.nan)
# Out:
# 0        Kowloon Bay
# 1            Tai Koo
# 2       Ngau Tau Kok
# 3      Lantau Island
# 4                NaN
#            ...
# 344              NaN
# 345         Wan Chai
# 346         Wan Chai
# 347    Tseung Kwan O
# 348    Lantau Island
# Name: district, Length: 349, dtype: object

# %%
def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None

df_1[['Latitude', 'Longitude']] = df_1.apply(lambda x: my_geocoder(x['district']), axis=1)

print("{}% of addresses were geocoded!".format(
    (1 - sum(np.isnan(df_1["Latitude"])) / len(df_1)) * 100))
# Out:
# 99.7134670487106% of addresses were geocoded!

# %%
# Drop universities that were not successfully geocoded

df_2 = gpd.GeoDataFrame(
    df_1, geometry=gpd.points_from_xy(df_1.Longitude, df_1.Latitude))
df_2.crs = {'init': 'epsg:4326'}
# Out:
# C:\Users\User\miniconda3\envs\hkjobsdb_scrap\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
df_2
# Out:
#                                                  title  salary  \
# 0                                       Data Scientist  salary
# 1                             Data Analyst (Data & AI)  salary
# 2                       Data Analyst (Data Governance)  salary
# 3            Solution Analyst - ICC - Data Integration  salary
# 4                  Analyst Programmer (Data Analytics)  salary
# ..                                                 ...     ...
# 344  Regional Senior Manager, Enterprise Architectu...  salary
# 345          Senior Data Engineer (Financial Services)  salary
# 346                       Data Engineer / Data Analyst  salary
# 347                  Senior Business Analysis Engineer  salary
# 348         Receptionist (1-year contract, Up to $19K)  salary
#
#                                                company      posted  \
# 0                               Connexe Search Limited  2022-12-06
# 1                                    NCSI (HK) Limited  2022-12-06
# 2              Gientech Technology (Hong Kong) Limited  2022-12-06
# 3                           Cathay Pacific Airways Ltd  2022-12-06
# 4    China State Construction Engineering (Hong Kon...  2022-12-06
# ..                                                 ...         ...
# 344                                       Michael Page  2022-11-09
# 345                   Emperor Financial Services Group  2022-11-08
# 346               eCloudvalley Technology (HK) Limited  2022-11-07
# 347        China Unicom (Hong Kong) Operations Limited  2022-11-07
# 348              Manpower Services (Hong Kong) Limited  2022-12-06
#
#           district                                    job_description  \
# 0      Kowloon Bay  Our client is one of the leading financial ins...
# 1          Tai Koo  Key Role Responsibilities:\n\nParticipate in c...
# 2     Ngau Tau Kok  Duties:\nManage & support data governance mode...
# 3    Lantau Island  Reports to: Solution Lead / Senior Solution Le...
# 4         district  Job Description:\nEstablish and maintain high-...
# ..             ...                                                ...
# 344       district  Large conglomerate\nGroup Head Office\nDigital...
# 345       Wan Chai  Job Description \nTo design, implement and mai...
# 346       Wan Chai  Job Duties\nBuild end-to-end data architecture...
# 347  Tseung Kwan O  Job Description\n\n1. Responsible for the plan...
# 348  Lantau Island  Responsibilitlies:\nManage reception counter t...
#
#     Career Level Years of Experience                       Company Website  \
# 0            NaN                 NaN                                   NaN
# 1            NaN                 NaN                  http://www.ncs-i.com
# 2         Middle             3 years                                   NaN
# 3            NaN                 NaN  http://www.cathaypacific.com/careers
# 4    Entry Level             3 years           https://www.cscechk.com/en/
# ..           ...                 ...                                   ...
# 344       Senior             9 years         http://www.michaelpage.com.hk
# 345       Middle             5 years                                   NaN
# 346  Entry Level                 NaN                                   NaN
# 347       Middle                 NaN   http://www.chinaunicomglobal.com/hk
# 348  Entry Level             2 years        http://www.manpowergroupgrc.hk
#
#     Qualification              Job Type  \
# 0             NaN              Contract
# 1             NaN  Full Time, Permanent
# 2          Degree  Full Time, Permanent
# 3             NaN  Full Time, Permanent
# 4          Degree  Full Time, Permanent
# ..            ...                   ...
# 344        Degree  Full Time, Permanent
# 345        Degree  Full Time, Permanent
# 346           NaN  Full Time, Permanent
# 347        Degree  Full Time, Permanent
# 348        Degree              Contract
#
#                                          Job Functions  \
# 0    Banking / Finance, Others, Information Technol...
# 1    Information Technology (IT), Product Managemen...
# 2          Information Technology (IT), Data Scientist
# 3    Transportation & Logistics, Aviation Services,...
# 4    Information Technology (IT), DBA, Others, Data...
# ..                                                 ...
# 344  Professional Services, Business Analysis / Dat...
# 345  Information Technology (IT), DBA, Software Dev...
# 346  Information Technology (IT), Product Managemen...
# 347  Information Technology (IT), DBA, Product Mana...
# 348                           Admin & HR, Receptionist
#
#                                                    url   Latitude   Longitude  \
# 0    https://hk.jobsdb.com/hk/en/job/data-scientist...  22.323467  114.214068
# 1    https://hk.jobsdb.com/hk/en/job/data-analyst-d...  22.284532  114.216352
# 2    https://hk.jobsdb.com/hk/en/job/data-analyst-d...  22.315512  114.219092
# 3    https://hk.jobsdb.com/hk/en/job/solution-analy...  22.271703  113.957319
# 4    https://hk.jobsdb.com/hk/en/job/analyst-progra...  33.811953  -84.378525
# ..                                                 ...        ...         ...
# 344  https://hk.jobsdb.com/hk/en/job/regional-senio...  33.811953  -84.378525
# 345  https://hk.jobsdb.com/hk/en/job/senior-data-en...  22.279015  114.172483
# 346  https://hk.jobsdb.com/hk/en/job/data-engineer-...  22.279015  114.172483
# 347  https://hk.jobsdb.com/hk/en/job/senior-busines...  22.292258  114.257724
# 348  https://hk.jobsdb.com/hk/en/job/receptionist-1...  22.271703  113.957319
#
#                        geometry
# 0    POINT (114.21407 22.32347)
# 1    POINT (114.21635 22.28453)
# 2    POINT (114.21909 22.31551)
# 3    POINT (113.95732 22.27170)
# 4    POINT (-84.37852 33.81195)
# ..                          ...
# 344  POINT (-84.37852 33.81195)
# 345  POINT (114.17248 22.27901)
# 346  POINT (114.17248 22.27901)
# 347  POINT (114.25772 22.29226)
# 348  POINT (113.95732 22.27170)
#
# [349 rows x 16 columns]

# %%
df_2.to_csv('geo_data.csv', index = False)

# %%
df_3 = df_2[df_2['district'].notna()]
df_3 = df_3[df_3['Latitude'].notna()]
df_3 = df_3[df_3['Longitude'].notna()]
df_3 = df_3[df_3['geometry'].notna()]

# %%
df_3.isna().sum()
# Out:
# title                    0
# salary                   0
# company                  0
# posted                   0
# district                 0
# job_description          0
# Career Level            84
# Years of Experience    115
# Company Website        133
# Qualification           67
# Job Type                 0
# Job Functions            0
# url                      0
# Latitude                 0
# Longitude                0
# geometry                 0
# dtype: int64

# %%
# further cleanup 
to_drop = ['district',
            'Aberdeen',
            'Overseas',
            'Others',
            'Southern Area']
for i in to_drop:
    df_3.drop(df_3.loc[df_3['district']==i].index, inplace=True)

# %%
# Create a map
m = folium.Map(location=[22.34, 114.1], tiles='openstreetmap', zoom_start=11, control_scale=True)

# Add points to the map
for idx, row in df_3.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['district']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aafef1e376102d4228b1ce8a8ebe1c18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aafef1e376102d4228b1ce8a8ebe1c18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aafef1e376102d4228b1ce8a8ebe1c18 = L.map(
#                 &quot;map_aafef1e376102d4228b1ce8a8ebe1c18&quot;,
#                 {
#                     center: [22.34, 114.1],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#
#
#
#             var tile_layer_1d3c441acc85fbd9b6f72eb8cd94f7fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#             var marker_65230bc68b1bd7cd1e792a9e1f7ece0b = L.marker(
#                 [22.323467299999997, 114.21406755240673],
#                 {}
#             ).addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#         var popup_566f44b6063df08979d3a3ae3901f424 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ddce97a974e02d58ca47978c95572912 = $(`&lt;div id=&quot;html_ddce97a974e02d58ca47978c95572912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kowloon Bay&lt;/div&gt;`)[0];
#                 popup_566f44b6063df08979d3a3ae3901f424.setContent(html_ddce97a974e02d58ca47978c95572912);
#
#
#
#         marker_65230bc68b1bd7cd1e792a9e1f7ece0b.bindPopup(popup_566f44b6063df08979d3a3ae3901f424)
#         ;
#
#
#
#
#             var marker_88dba1485645b960415066f1346e8e99 = L.marker(
#                 [22.2845316, 114.2163521],
#                 {}
#             ).addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#         var popup_0c0b8ee9abfc648c0a591e209ab9bac1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbda654e8dd00cd88be03e45b744b4ec = $(`&lt;div id=&quot;html_fbda654e8dd00cd88be03e45b744b4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tai Koo&lt;/div&gt;`)[0];
#                 popup_0c0b8ee9abfc648c0a591e209ab9bac1.setContent(html_fbda654e8dd00cd88be03e45b744b4ec);
#
#
#
#         marker_88dba1485645b960415066f1346e8e99.bindPopup(popup_0c0b8ee9abfc648c0a591e209ab9bac1)
#         ;
#
#
#
#
#             var marker_ca8fe4e576701235757fbad115c7a07a = L.marker(
#                 [22.315511649999998, 114.21909231828533],
#                 {}
#             ).addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#         var popup_04824cec88788928629e31ea509ff8ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_616865f622cc580266f26909012c1633 = $(`&lt;div id=&quot;html_616865f622cc580266f26909012c1633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ngau Tau Kok&lt;/div&gt;`)[0];
#                 popup_04824cec88788928629e31ea509ff8ee.setContent(html_616865f622cc580266f26909012c1633);
#
#
#
#         marker_ca8fe4e576701235757fbad115c7a07a.bindPopup(popup_04824cec88788928629e31ea509ff8ee)
#         ;
#
#
#
#
#             var marker_541c38796baea5d0b2d703d783cd93ce = L.marker(
#                 [22.271703, 113.9573191],
#                 {}
#             ).addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#         var popup_3930b7ad3bb8ccf34ac511544b5a2b35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3de3f220e85f4cd4e18b4406f94305f = $(`&lt;div id=&quot;html_f3de3f220e85f4cd4e18b4406f94305f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lantau Island&lt;/div&gt;`)[0];
#                 popup_3930b7ad3bb8ccf34ac511544b5a2b35.setContent(html_f3de3f220e85f4cd4e18b4406f94305f);
#
#
#
#         marker_541c38796baea5d0b2d703d783cd93ce.bindPopup(popup_3930b7ad3bb8ccf34ac511544b5a2b35)
#         ;
#
#
#
#
#             var marker_37bc1bc749eaae6c4140bdf4f7a7c87a = L.marker(
#                 [22.323467299999997, 114.21406755240673],
#                 {}
#             ).addTo(map_aafef1e376102d4228b1ce8a8ebe1c18);
#
#
#         var popup_ed5edc9134d251882f91a129d4586874 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47be28af2e3b739c37bd06ddd1645679 = $(`&lt;div id=&quot;html_47be28af2e3b739c37bd06ddd1645679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kowloon Bay&lt;/div&gt;`)[0];
#                 popup_ed5edc9134d251882f91a129d4586874.setContent(html_47be28af2e3b739c37bd06ddd1645679);
#
#
#
#         marker_37bc1bc749eaae6c4140bdf4f7a7c87a.bindPopup(popup_ed5edc9134d251882f91a129d4586874)
#         ;
#
#
#
#
#             var marker_6d0b9e190c325a61b3c872d418bfd1e9 = L.marker(
#                 [22.2845316, 114.2163521],
#                 {}

# %%
m.save('hk_data_job_geodistribution.html')
